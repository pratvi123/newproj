# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import cross_validation
import matplotlib.pyplot as plt 
df=pd.read_csv(r'E:\AirPassengers.csv')
df
plt.plot(range(0,144),df['#Passengers'])
plt.show()

# %%
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# 5    1949-06          135
# 6    1949-07          148
# 7    1949-08          148
# 8    1949-09          136
# 9    1949-10          119
# 10   1949-11          104
# 11   1949-12          118
# 12   1950-01          115
# 13   1950-02          126
# 14   1950-03          141
# 15   1950-04          135
# 16   1950-05          125
# 17   1950-06          149
# 18   1950-07          170
# 19   1950-08          170
# 20   1950-09          158
# 21   1950-10          133
# 22   1950-11          114
# 23   1950-12          140
# 24   1951-01          145
# 25   1951-02          150
# 26   1951-03          178
# 27   1951-04          163
# 28   1951-05          172
# 29   1951-06          178
# ..       ...          ...
# 114  1958-07          491
# 115  1958-08          505
# 116  1958-09          404
# ...

# %%
y=lambda x:x+2

# %%
y(2)
# Out:
# 4

# %%
# Out:
# ['1949-01',
#  '1949-02',
#  '1949-03',
#  '1949-04',
#  '1949-05',
#  '1949-06',
#  '1949-07',
#  '1949-08',
#  '1949-09',
#  '1949-10',
#  '1949-11',
#  '1949-12',
#  '1950-01',
#  '1950-02',
#  '1950-03',
#  '1950-04',
#  '1950-05',
#  '1950-06',
#  '1950-07',
#  '1950-08',
#  '1950-09',
#  '1950-10',
#  '1950-11',
#  '1950-12',
#  '1951-01',
#  '1951-02',
#  '1951-03',
#  '1951-04',
#  '1951-05',
#  '1951-06',
#  '1951-07',
#  '1951-08',
#  '1951-09',
#  '1951-10',
#  '1951-11',
#  '1951-12',
#  '1952-01',
#  '1952-02',
#  '1952-03',
#  '1952-04',
#  '1952-05',
#  '1952-06',
#  '1952-07',
#  '1952-08',
#  '1952-09',
#  '1952-10',
#  '1952-11',
#  '1952-12',
#  '1953-01',
#  '1953-02',
#  '1953-03',
#  '1953-04',
#  '1953-05',
#  '1953-06',
#  '1953-07',
#  '1953-08',
#  '1953-09',
#  '1953-10',
#  '1953-11',
#  '1953-12',
#  '1954-01',
#  '1954-02',
#  '1954-03',
#  '1954-04',
#  '1954-05',
#  '1954-06',
#  '1954-07',
#  '1954-08',
#  '1954-09',
#  '1954-10',
#  '1954-11',
# ...

# %%
dateparse=lambda dates: pd.datetime.strptime(dates,'%Y-%m')

# %%
data= pd.read_csv(r'E:\AirPassengers.csv', parse_dates=['Month'],index_col='Month' ,date_parser=dateparse)
print data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
plt.plot(data)
plt.show()

# %%
data.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name=u'Month', length=144, freq=None)

# %%
from statsmodels.tsa.stattools import adfuller
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data_log=np.log(data)    #log of data(to get stationary on data)
data_log
plt.plot(data_log)
plt.show()

# %%
moving_avg=pd.rolling_mean(data_log,12)
moving_avg
plt.plot(moving_avg)
plt.plot(data_log)
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
data_log_moving_avg_diff=data_log-moving_avg
data_log_moving_avg_diff
plt.plot(data_log_movi)
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01    -0.065494
# 1950-01-01    -0.093449
# 1950-02-01    -0.007566
# 1950-03-01     0.099416
# 1950-04-01     0.052142
# 1950-05-01    -0.027529
# 1950-06-01     0.139881
# 1950-07-01     0.260184
# 1950-08-01     0.248635
# 1950-09-01     0.162937
# 1950-10-01    -0.018578
# 1950-11-01    -0.180379
# 1950-12-01     0.010818
# 1951-01-01     0.026593
# 1951-02-01     0.045965
# 1951-03-01     0.197694
# 1951-04-01     0.093955
# 1951-05-01     0.121101
# 1951-06-01     0.140570
# ...                 ...
# 1958-07-01     0.276817
# 1958-08-01     0.298412
# 1958-09-01     0.075268
# 1958-10-01    -0.045657
# 1958-11-01    -0.193762
# 1958-12-01    -0.110499
# ...
